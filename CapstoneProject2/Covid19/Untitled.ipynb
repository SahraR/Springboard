# %%
import pandas as pd 
df1 = pd.read_csv('/Users/sahrarahim/Desktop/Springboard/CapstoneProject2/Covid19/Dataset/Covid19Canada/timeseries_prov/active_timeseries_prov.csv')
df1.head()
# Out:
#   province date_active  cumulative_cases  cumulative_recovered  \
# 0  Alberta  25-01-2020                 0                     0
# 1  Alberta  26-01-2020                 0                     0
# 2  Alberta  27-01-2020                 0                     0
# 3  Alberta  28-01-2020                 0                     0
# 4  Alberta  29-01-2020                 0                     0
#
#    cumulative_deaths  active_cases  active_cases_change
# 0                  0             0                    0
# 1                  0             0                    0
# 2                  0             0                    0
# 3                  0             0                    0
# 4                  0             0                    0

# %%
df1['province'].value_counts()
# Out:
# Yukon            429
# Quebec           429
# Nunavut          429
# Ontario          429
# Manitoba         429
# Nova Scotia      429
# Saskatchewan     429
# Alberta          429
# NL               429
# New Brunswick    429
# NWT              429
# PEI              429
# BC               429
# Repatriated      429
# Name: province, dtype: int64

# %%
df1.shape
# Out:
# (6006, 7)

# %%
df1['date_active']=pd.to_datetime(df1['date_active'])

# %%
import seaborn as sns

sns.lineplot(x="date_active", y="active_cases",
             hue="province", data=df1)
# Out:
# <AxesSubplot:xlabel='date_active', ylabel='active_cases'>

# %%
df1.isnull().sum()
# Out:
# province                0
# date_active             0
# cumulative_cases        0
# cumulative_recovered    0
# cumulative_deaths       0
# active_cases            0
# active_cases_change     0
# dtype: int64

# %%
df1.tail()
# Out:
#      province date_active  cumulative_cases  cumulative_recovered  \
# 6001    Yukon  2021-03-24                72                    71
# 6002    Yukon  2021-03-25                73                    71
# 6003    Yukon  2021-03-26                73                    71
# 6004    Yukon  2021-03-27                73                    71
# 6005    Yukon  2021-03-28                73                    71
#
#       cumulative_deaths  active_cases  active_cases_change
# 6001                  1             0                    0
# 6002                  1             1                    1
# 6003                  1             1                    0
# 6004                  1             1                    0
# 6005                  1             1                    0
